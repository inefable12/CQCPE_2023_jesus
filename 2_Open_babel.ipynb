# %% [markdown]
# <a href="https://colab.research.google.com/github/inefable12/CQCPE_2023_jesus/blob/main/2_Open_babel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get -qq install -y openbabel
# Out:
# Selecting previously unselected package libinchi1.
# (Reading database ... 120901 files and directories currently installed.)
# Preparing to unpack .../libinchi1_1.03+dfsg-4_amd64.deb ...
# Unpacking libinchi1 (1.03+dfsg-4) ...
# Selecting previously unselected package libmaeparser1:amd64.
# Preparing to unpack .../libmaeparser1_1.2.4-1build1_amd64.deb ...
# Unpacking libmaeparser1:amd64 (1.2.4-1build1) ...
# Selecting previously unselected package libopenbabel7.
# Preparing to unpack .../libopenbabel7_3.1.1+dfsg-6ubuntu5_amd64.deb ...
# Unpacking libopenbabel7 (3.1.1+dfsg-6ubuntu5) ...
# Selecting previously unselected package openbabel.
# Preparing to unpack .../openbabel_3.1.1+dfsg-6ubuntu5_amd64.deb ...
# Unpacking openbabel (3.1.1+dfsg-6ubuntu5) ...
# Setting up libmaeparser1:amd64 (1.2.4-1build1) ...
# Setting up libinchi1 (1.03+dfsg-4) ...
# Setting up libopenbabel7 (3.1.1+dfsg-6ubuntu5) ...
# Setting up openbabel (3.1.1+dfsg-6ubuntu5) ...
# ...

# %%
# !obabel -i smi parababel.smi -o sdf --gen3D > output.sdf
# Out:
# 4 molecules converted

# %%
# !grep WARNING output.sdf

# %%
# !obabel -i sdf output.sdf -o mol2 -O _.mol2 -h -m
# Out:
# 4 molecules converted
# 4 files output. The first is _1.mol2

# %%
# !obabel *.mol2 -O opt.xyz --minimize --sd --steps 20000 --ff MMFF94 -p 7.4 --log -m
# Out:
# A T O M   T Y P E S
#
# IDX	TYPE	RING
# 1	1	NO
# 2	3	NO
# 3	7	NO
# 4	6	NO
# 5	37	AR
# 6	37	AR
# 7	37	AR
# 8	37	AR
# 9	37	AR
# 10	37	AR
# 11	3	NO
# 12	7	NO
# 13	6	NO
# 14	5	NO
# 15	5	NO
# 16	5	NO
# 17	5	NO
# 18	5	NO
# 19	5	NO
# 20	5	NO
# 21	24	NO
#
# F O R M A L   C H A R G E S
#
# IDX	CHARGE
# 1	0.000000
# 2	0.000000
# 3	0.000000
# 4	0.000000
# 5	0.000000
# 6	0.000000
# 7	0.000000
# 8	0.000000
# 9	0.000000
# 10	0.000000
# 11	0.000000
# 12	0.000000
# 13	0.000000
# 14	0.000000
# 15	0.000000
# 16	0.000000
# 17	0.000000
# 18	0.000000
# 19	0.000000
# 20	0.000000
# 21	0.000000
#
# P A R T I A L   C H A R G E S
#
# IDX	CHARGE
# 1	0.061000
# 2	0.659000
# 3	-0.570000
# 4	-0.232500
# 5	0.082500
# 6	-0.150000
# 7	-0.150000
# 8	-0.150000
# 9	-0.150000
# 10	0.086200
# 11	0.633800
# 12	-0.570000
# 13	-0.650000
# 14	0.000000
# 15	0.000000
# 16	0.000000
# 17	0.150000
# 18	0.150000
# 19	0.150000
# 20	0.150000
# 21	0.500000
#
# S E T T I N G   U P   C A L C U L A T I O N S
#
# ...

# %%
# !obabel -i xyz *.xyz -o pdbqt -O lig_.pdbqt -m
# Out:
# 4 molecules converted
# 4 files output. The first is lig_opt_1.pdbqt

# %%
# !ls *xyz | wc -l
# Out:
# 4

# %%
#!mkdir mis_inputs_vina
#!mv *.pdbqt /content/mis_inputs_vina

# %%
# !zip mis_inputs_vina.zip /content/mis_inputs_vina/*.pdbqt
# Out:
#   adding: content/mis_inputs_vina/lig_opt_1.pdbqt (deflated 70%)
#   adding: content/mis_inputs_vina/lig_opt_2.pdbqt (deflated 72%)
#   adding: content/mis_inputs_vina/lig_opt_3.pdbqt (deflated 71%)
#   adding: content/mis_inputs_vina/lig_opt_4.pdbqt (deflated 69%)
